# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sp
# %matplotlib inline

# %% [markdown]
# **1.Filling the area between line graphs***

# %%
#Filling the graph area
x=np.linspace(0,10,100)
y=x**2
plt.plot(x,y,'or')
plt.fill_between(x, y, color='blue')
plt.title('How to fill an area in matplotlib ?',fontsize=15)
# Out:
# Text(0.5, 1.0, 'How to fill an area in matplotlib ?')

# %%
#filling the opposite graph
plt.plot(x,y,'--b')
plt.fill_between(x, y,np.max(y), color='red')

# %%
y1=np.sin(x)
plt.plot(x,y1)
plt.fill_between(x,y1,color='green')

# %%
y1=np.exp(-x)
y2=np.log(x)
plt.plot(x,y1,'--r',x,y2,'b')
plt.fill_between(x,y1,y2,color='red')
# Out:
# C:\Users\DeLL\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
#Imshow
x1=np.zeros((10,10))
plt.subplot(1,2,1)
plt.imshow(x1)
x2=np.ones((10,10))
plt.subplot(1,2,2)
plt.imshow(x2)

# %%
import matplotlib.image as mpimg

# %%
image=mpimg.imread('nibbi.jpg')
#print(image)
print(np.shape(image))
# Out:
# (606, 800, 3)

# %%
plt.imshow(image)

# %%
image2=image[:, :, 0]
plt.imshow(image2)

# %%
plt.imshow(image2,cmap='hot')

# %%
plt.hist(image2.ravel())
# Out:
# (array([ 38522., 152182., 111464.,  45480.,  59461.,  35225.,  25650.,
#           3338.,    541.,  12937.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# **3-Log Plot in Matplotlib**

# %%
x = np.linspace(0.01, 5, 10000)
y=x**2
plt.subplot(1,2,1)
plt.plot(x,y)
plt.subplot(1,2,2)
plt.loglog(x,y)

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# **5-Annotating text**

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# **6-contour plots**

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, colors='black')

# %%
plt.contour(X, Y, Z, 20, cmap='RdGy');

# %%
plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar();

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, normed=True, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);
# Out:
# C:\Users\DeLL\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   import sys
# C:\Users\DeLL\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#
# C:\Users\DeLL\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   if __name__ == '__main__':

# %%
x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sine')
ax.plot(x, np.cos(x), '--r', label='Cosine')
ax.axis('equal')
leg = ax.legend();

# %%
fig, ax = plt.subplots(4, 4, sharex=True, sharey=True)

# %%
for i in range(4):
    plt.plot(np.random.rand(10));
    plt.grid()
